# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
iRisData = pd.read_csv('iris.csv')
withoutSepal = iRisData.drop(['sepal_length', 'sepal_width'],axis=1)
withoutSepal
# Out:
#      petal_length  petal_width           class
# 0             1.4          0.2     Iris-setosa
# 1             1.4          0.2     Iris-setosa
# 2             1.3          0.2     Iris-setosa
# 3             1.5          0.2     Iris-setosa
# 4             1.4          0.2     Iris-setosa
# ..            ...          ...             ...
# 145           5.2          2.3  Iris-virginica
# 146           5.0          1.9  Iris-virginica
# 147           5.2          2.0  Iris-virginica
# 148           5.4          2.3  Iris-virginica
# 149           5.1          1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %%
plt.plot(withoutSepal['petal_length'], withoutSepal['petal_width'], 'o')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
##for optimal line i should implement lienar droite
##i choose randomly w, b and x, for the equation y = b + wx

# %%
#w = 1
#b = 1
#x = withoutSepal['petal_length']
#y = w + (b * x)

# %%
## i can manually ajust b and w to find the optimal line to predict my data
w = -0.4
b = 0.4
x = withoutSepal['petal_length']
y = w + (b * x)

plt.plot(withoutSepal['petal_length'], withoutSepal['petal_width'], 'o', label='withoutSepal')
plt.plot(x, y, label='predictions')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.legend()
plt.show()

# %%
##i use 5 for example but it can be any value of x
y_predite = w + (b * 5)
y_predite
# Out:
# 1.6
